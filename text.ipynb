# %%
num =-5
print(abs(num))
lists = [-12,45,-90,79,-60]
for a in lists:
    print(abs(a))
# Out:
# 5
# 12
# 45
# 90
# 79
# 60

# %%
s = {1,8,2,3}
print(len(s))
s.remove(8)
print(s)
# Out:
# 4
# {1, 2, 3}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 5
#       1 s = {1,8,2,3}
#       2 print(len(s))
#       3 s.remove(8)
#       4 print(s)
# ----> 5 s.pop(2)
#       6 print(s)
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
a = {1,2,3,4,4,4,4}
print(a)
a.add(544)
print(a)
print(len(a))
# Out:
# {1, 2, 3, 4}
# {544, 1, 2, 3, 4}
# 5

# %%
words ={
   "key" : "value",
   "maded":"help",
   "maja": "injoy",
   "kursi": "chair"
}
word = input("enter a word")
print(words[word])

# %%
d = {"a": 10, "b": 20, "c": 30}
d.popitem()
print(d)
d.copy()
print(d)
# Out:
# {'a': 10, 'b': 20}
# {'a': 10, 'b': 20}

# %%
print("hello")
# Out:
# hello

# %%
a= {"key":"value",
    "harry": "code",
    "marks": "100",
    "list": [1,2,3]
    }
print(a.items())
print(a.keys())
print(a.values())
# print(a.keys())
a.update({"harry":99 , "nikhil":100})
print(a)
print(a.get("harry2"))
print(a["harry"])
a.pop("harry")
print(a)
# Out:
# dict_items([('key', 'value'), ('harry', 'code'), ('marks', '100'), ('list', [1, 2, 3])])
# dict_keys(['key', 'harry', 'marks', 'list'])
# dict_values(['value', 'code', '100', [1, 2, 3]])
# {'key': 'value', 'harry': 99, 'marks': '100', 'list': [1, 2, 3], 'nikhil': 100}
# None
# 99
# {'key': 'value', 'marks': '100', 'list': [1, 2, 3], 'nikhil': 100}

# %%
sorts= [1,4,2,3,4,5,6]
sorts.sort()
print(sorts)
print(len(sorts))
for i in sorts:
    print(i)
print(2 in sorts)
s=[x* x for x in range(1,6)]
print(s)
# Out:
# [1, 2, 3, 4, 4, 5, 6]
# 7
# 1
# 2
# 3
# 4
# 4
# 5
# 6
# True
# [1, 4, 9, 16, 25]

# %%
marks = []
m1 = int(input("enter marks"))
marks.append(m1)
m2 = int(input("enter marks"))
marks.append(m2)
m3 = int(input("enter marks"))
marks.append(m3)
m4 = int(input("enter marks"))
marks.append(m4)
m5 = int(input("enter marks"))
marks.append(m5)
m6 = int(input("enter marks"))
marks.append(m6)
print(marks)
# Out:
# [8, 8, 8, 8, 8, 8]

# %%
fruits = []
f1 = input("enter a fruit name :")
fruits.append(f1)
f2 = input("enter a fruit name :")
fruits.append(f2)
print(fruits)
# Out:
# ['8', '8']

# %%
a = (1,2,3,4)
print(a[::-1])
# Out:
# (4, 3, 2, 1)
