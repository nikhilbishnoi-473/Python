# %%
def square_Num(n):
    sq = n*n
    return sq
square_Num(5)
result= square_Num(5)
print(result)
pl = result + 10
print(pl)
# Out:
# 25
# 35

# %%
def fact(n):
    if (n ==0 or n ==1):
        return 1
    return n * fact(n-1)
n = int(input("enter the number :"))
fact(n)
# Out:
# 120

# %%
def numbers(a,b,c):
    if a > b and a > c:
        return a
    elif b> a and b> c :
        return b
    else:
        return c
n=numbers(2,3,4)
print(n)
# Out:
# 4

# %%
def table(a):
    for i in range(1,11):
        print(f"{a} * {i} =", (a*i))
table(4)
# Out:
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 4 * 6 = 24
# 4 * 7 = 28
# 4 * 8 = 32
# 4 * 9 = 36
# 4 * 10 = 40

# %%
def user_Name(username):
    print(username)
def add(a,b):
    res = a+b
    print(res)

user_Name("nikhil bishnoi")
user_Name("bishnoi")
add(10,20)
# Out:
# nikhil bishnoi
# bishnoi
# 30

# %%
a= "helo"
print(f"{a}")
n= 4.22213
print(round(n,2))
m= -20
print(abs(m))
nn = 10
print(abs(m+nn))
print(round(n))
list =[-10, 20, -30, -40]
for i in list:
    print(abs(i))
# Out:
# helo
# 4.22
# 20
# 10
# 4
# 10
# 20
# 30
# 40

# %%
list = [10,20,-30,-40,50]
print(sum(list))
print(max(list))
print(len(list))
# Out:
# 10
# 50
# 5

# %%
i=[10,-30,40,-50,20]
for j in i: 
    print(abs(j))
num = len(i)
print(f"length of list: {num}")
min_Num= min(i)
max_Num = max(i)
print(f"min numbers in :{min_Num}")
print(f"max numbers in :{max_Num}")
sum_Num = sum(i)
avg = sum_Num/num
print(avg)
print(type(i))
# Out:
# 10
# 30
# 40
# 50
# 20
# length of list: 5
# min numbers in :-50
# max numbers in :40
# -2.0
# <class 'list'>

# %%
def function_name():
    print("hello")
    print("world")
function_name()
# Out:
# hello
# world

# %%
def day(name, end="thank you"):
    print(f"{name} {end}")
day("nikhil" )
# Out:
# nikhil thank you
