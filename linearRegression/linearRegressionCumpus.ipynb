# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/nikhilbishnoi/Desktop/python/placement_data.csv/placement_data.csv')
df.head()
# Out:
#    CGPA  Placement_Package_LPA
# 0  6.87                   9.06
# 1  9.75                  13.43
# 2  8.66                  12.19
# 3  7.99                  10.37
# 4  5.78                  10.30

# %%
plt.scatter(df['CGPA'], df['Placement_Package_LPA'])
plt.xlabel("CGPA")
plt.ylabel("Placement_Package_LPA")
# Out:
# Text(0, 0.5, 'Placement_Package_LPA')

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
X
# Out:
#      CGPA
# 0    6.87
# 1    9.75
# 2    8.66
# 3    7.99
# 4    5.78
# ..    ...
# 195  6.75
# 196  8.63
# 197  9.49
# 198  9.44
# 199  8.90
#
# [200 rows x 1 columns]

# %%
y
# Out:
# 0       9.06
# 1      13.43
# 2      12.19
# 3      10.37
# 4      10.30
#        ...
# 195     8.19
# 196    11.14
# 197    12.67
# 198    13.14
# 199    13.66
# Name: Placement_Package_LPA, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train , y_test = train_test_split(X,y ,test_size=0.2, random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#      CGPA
# 112  9.65
# 29   5.23
# 182  9.62
# 199  8.90
# 193  8.17
# 85   6.63
# 10   5.10
# 54   7.99
# 115  9.36
# 35   9.04
# 12   9.16
# 92   8.80
# 13   6.06
# 126  9.09
# 174  8.23
# 2    8.66
# 44   6.29
# 3    7.99
# 113  9.04
# 14   5.91
# 23   6.83
# 25   8.93
# 6    5.29
# 134  9.71
# 165  9.18
# 173  6.13
# 45   8.31
# 65   7.71
# 48   7.73
# 122  6.59
# 178  9.68
# 64   6.40
# 9    8.54
# 57   5.98
# 78   6.79
# 71   5.99
# 128  5.03
# 176  8.45
# 131  6.11
# 53   9.47

# %%
y_test
# Out:
# 112    12.83
# 29      6.92
# 182    14.02
# 199    13.66
# 193    11.54
# 85      9.64
# 10      8.78
# 54     11.60
# 115    11.30
# 35     12.28
# 12     13.46
# 92     10.86
# 13      9.18
# 126    12.48
# 174    12.53
# 2      12.19
# 44      8.16
# 3      10.37
# 113    11.10
# 14      9.41
# 23     10.52
# 25     13.67
# 6       6.66
# 134    13.00
# 165    12.21
# 173     7.64
# 45     11.63
# 65     10.52
# 48     11.13
# 122     8.43
# 178    13.10
# 64      8.41
# 9      12.54
# 57     12.53
# 78      8.92
# 71      7.08
# 128     7.65
# 176    12.26
# 131     7.59
# 53     11.93
# Name: Placement_Package_LPA, dtype: float64

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# /Users/nikhilbishnoi/Desktop - Nikhil’s MacBook Air - 1/python/.venv/lib/python3.14/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([13.09890172])

# %%
plt.scatter(df["CGPA"], df["Placement_Package_LPA"])
plt.plot(X_test, lr.predict(X_test), color="red")
plt.xlabel("CGPA")
plt.ylabel("Placement_Package_LPA")
# Out:
# Text(0, 0.5, 'Placement_Package_LPA')

# %%
m= lr.coef_

# %%
b= lr.intercept_

# %%
#y = mx+b
m * 9.65+b
# Out:
# array([13.09890172])
