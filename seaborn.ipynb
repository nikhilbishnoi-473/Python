# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt
var = [1,2,3,4,5,6]
var_r = [6,2,5,3,5,1]
plt.plot(var, var_r)
plt.show()

# %%
import seaborn as sns
import pandas as pd 
var = [1,2,3,4,5,6]
var_r = [6,2,5,3,5,1]
data = pd.DataFrame({"var":var,"var_r":var_r})
sns.lineplot(x="var",y="var_r", data=data)
# sns.show()
# Out:
# <Axes: xlabel='var', ylabel='var_r'>

# %%
import seaborn as sns
import pandas as pd 
y_1 = pd.read_csv("/Users/nikhilbishnoi/Desktop/python/penguins.csv")
print(y_1)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
peng= sns.load_dataset("penguins").head(20)

# %%
peng["species"].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
peng["0"].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
sns.lineplot(x="bill_length_mm",y="bill_depth_mm",data=peng,size=10,hue="sex", style="sex",palette="Accent", markers=["o", ">"],dashes=False,legend="full")
plt.grid()
plt.title("Python Table")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
var= sns.load_dataset("penguins")
var
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.set(style="dark")
order_1 = ["Adelie","Gentoo", "Chinstrap"]
plt.figure(figsize=(4,5))
sns.barplot(x="species", y="bill_length_mm", data=var,hue="sex" ,order=order_1,hue_order=["Female","Male"] ,n_boot=30,saturation=100,errcolor="r",capsize=0.4,alpha=0.6)
# Out:
# /var/folders/_9/51dzwj1s109f2nh69j4_1ddr0000gn/T/ipykernel_49255/1351758347.py:4: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'r'}` instead.
#
#   sns.barplot(x="species", y="bill_length_mm", data=var,hue="sex" ,order=order_1,hue_order=["Female","Male"] ,n_boot=30,saturation=100,errcolor="r",capsize=0.4,alpha=0.6)
# <Axes: xlabel='species', ylabel='bill_length_mm'>

# %%
# Out:
#   Cell In[89], line 3
#     sns.barplot(x="bill_depth_mm" , y="bill_length_mm", data=var, hue="sex" ,hue="sex",order=order_1,hue_order=["Female","Male"])
#                                                                              ^
# SyntaxError: keyword argument repeated: hue
