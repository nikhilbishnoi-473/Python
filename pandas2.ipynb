# %%
import pandas as pd
import numpy as np

# Create DataFrame
df = pd.DataFrame({
    "name": ["nikhil", "bishnoi", "bhadu", "rohit"],
    "age": [20, 21, 22, 33],
    "rollNo": [29, 30, 31, 33]
}, index=["a", "b", "c", "d"])

print("Original DataFrame")
print(df)
# Out:
# Original DataFrame
#       name  age  rollNo
# a   nikhil   20      29
# b  bishnoi   21      30
# c    bhadu   22      31
# d    rohit   33      33

# %%
df.loc["a"]
# Out:
# name      nikhil
# age          100
# rollNo        29
# Name: a, dtype: object

# %%
print(df.loc[["a","c"]])
# Out:
#      name  age  rollNo
# a  nikhil   20      29
# c   bhadu   22      31

# %%
print(df.loc[:,"name"])
# Out:
# a     nikhil
# b    bishnoi
# c      bhadu
# d      rohit
# Name: name, dtype: str

# %%
print(df.loc[:, ["name", "age"]])
# Out:
#       name  age
# a   nikhil   20
# b  bishnoi   21
# c    bhadu   22
# d    rohit   33

# %%
print(df.loc["b" , "age"])
# Out:
# 21

# %%
print(df.loc[["a","c"],["name","rollNo"]])
# Out:
#      name  rollNo
# a  nikhil      29
# c   bhadu      31

# %%
print(df.loc["a":"c"])
# Out:
#       name  age  rollNo
# a   nikhil   20      29
# b  bishnoi   21      30
# c    bhadu   22      31

# %%
df.loc["c", "age"]= 25
df
# Out:
#       name  age  rollNo
# a   nikhil   20      29
# b  bishnoi   21      30
# c    bhadu   25      31
# d    rohit   33      33

# %%
df.loc[["a","b"],"age"]=[100,200]
df
# Out:
#       name  age  rollNo
# a   nikhil  100      29
# b  bishnoi  200      30
# c    bhadu   25      31
# d    rohit   33      33

# %%
df.loc[:,"marks"] = [80,60,70,80]
df
# Out:
#       name  age  rollNo  marks
# a   nikhil  100      29     80
# b  bishnoi  200      30     60
# c    bhadu   25      31     70
# d    rohit   33      33     80

# %%
print(df.loc[df["age"] < 45])
# Out:
#     name  age  rollNo  marks
# c  bhadu   25      31     70
# d  rohit   33      33     80

# %%
df.loc[df["age"] > 25, "Marks"] = 100
df
# Out:
#       name  age  rollNo  marks  Marks
# a   nikhil  100      29     80  100.0
# b  bishnoi  200      30     60  100.0
# c    bhadu   25      31     70    NaN
# d    rohit   33      33     80  100.0

# %%
df.loc[df["age"]> 30, "MARKS"]= 100
print(df)
# Out:
#       name  age  rollNo  marks  Marks  MARKS
# a   nikhil  100      29     80  100.0  100.0
# b  bishnoi  200      30     60  100.0  100.0
# c    bhadu   25      31     70    NaN    NaN
# d    rohit   33      33     80  100.0  100.0

# %%
df.loc["e"]= ["mohit", 26,35,88 , 0,0]
df
# Out:
#       name  age  rollNo  marks  Marks  MARKS
# a   nikhil  100      29     80  100.0  100.0
# b  bishnoi  200      30     60  100.0  100.0
# c    bhadu   25      31     70    NaN    NaN
# d    rohit   33      33     80  100.0  100.0
# e    mohit   26      35     88    0.0    0.0

# %%
print(df.loc["b":"d", "age":"Marks"])
# Out:
#    age  rollNo  marks  Marks
# b  200      30     60  100.0
# c   25      31     70    NaN
# d   33      33     80  100.0

# %%
print(df.loc[(df["age"] > 20) & (df["Marks"] >= 90)])
# Out:
#       name  age  rollNo  marks  Marks  MARKS
# a   nikhil  100      29     80  100.0  100.0
# b  bishnoi  200      30     60  100.0  100.0
# d    rohit   33      33     80  100.0  100.0

# %%
import pandas as pd
import numpy as np
newdf = pd.DataFrame(np.random.rand(6,5),index=np.arange(6))
# print(newdf)
newdf.columns = list("ABCDE") 
# print(newdf)
newdf.index= ["A","b","c","d","e","f"]
print(newdf)
# Out:
#           A         B         C         D         E
# A  0.470787  0.101617  0.461672  0.910881  0.536589
# b  0.192890  0.219533  0.052644  0.303114  0.518429
# c  0.770888  0.718056  0.481135  0.203464  0.998735
# d  0.466901  0.352548  0.246680  0.140636  0.458920
# e  0.849639  0.770402  0.459701  0.878856  0.970778
# f  0.759056  0.434658  0.638150  0.146909  0.064485

# %%
# newdf.drop(["A","B"], axis=1,inplace=True )
newdf.reset_index(drop=True,inplace=True)
newdf.head(3)
print(newdf)
newdf.loc[:,["B"]]= None
newdf
# Out:
#       B         D         E
# 0  None  0.910881  0.536589
# 1  None  0.303114  0.518429
# 2  None  0.203464  0.998735
# 3  None  0.140636  0.458920
# 4  None  0.878856  0.970778
# 5  None  0.146909  0.064485
#       B         D         E
# 0  None  0.910881  0.536589
# 1  None  0.303114  0.518429
# 2  None  0.203464  0.998735
# 3  None  0.140636  0.458920
# 4  None  0.878856  0.970778
# 5  None  0.146909  0.064485

# %%
print(df.drop([1,2], axis=0,inplace=True))
df.head(4)
# Out:
# None
#           b         d         e
# 0  0.924005  0.590092  0.248867
# 3  0.146651  0.227090  0.522606
# 4  0.634405  0.296164  0.907977
# 5  0.360890  0.623124  0.115997

# %%
df.reset_index(drop=True,inplace=True)
df.head(3)
# Out:
#           b         d         e
# 0  0.924005  0.590092  0.248867
# 1  0.350874  0.242003  0.791997
# 2  0.393636  0.040950  0.201933

# %%
df["d"].isnull()
df
# Out:
#            b         d         e     c
# 0   0.924005  0.590092  0.248867  None
# 3   0.146651  0.227090  0.522606  None
# 4   0.634405  0.296164  0.907977  None
# 5   0.360890  0.623124  0.115997  None
# 6   0.300445  0.783224  0.448824  None
# 7   0.875309  0.010303  0.435803  None
# 8   0.143958  0.182614  0.903378  None
# 9   0.449992  0.964743  0.242809  None
# 10  0.717517  0.973163  0.673969  None
# 11  0.604512  0.462088  0.986214  None
# 12  0.905127  0.415968  0.558411  None
# 13  0.483751  0.517467  0.886666  None
# 14  0.463231  0.009554  0.032222  None
# 15  0.700388  0.163386  0.788303  None
# 16  0.058124  0.128943  0.706653  None
# 17  0.339626  0.394312  0.293150  None
# 18  0.963115  0.545783  0.024147  None
# 19  0.878125  0.898241  0.726806  None
# 20  0.796752  0.417139  0.338135  None
# 21  0.364003  0.509557  0.986542  None
# 22  0.044668  0.496377  0.314951  None
# 23  0.676809  0.123125  0.190474  None
# 24  0.968860  0.196488  0.965115  None
# ...

# %%
df.reset_index()
# Out:
#     index         b         d         e     c
# 0       0  0.924005  0.590092  0.248867  None
# 1       3  0.146651  0.227090  0.522606  None
# 2       4  0.634405  0.296164  0.907977  None
# 3       5  0.360890  0.623124  0.115997  None
# 4       6  0.300445  0.783224  0.448824  None
# 5       7  0.875309  0.010303  0.435803  None
# 6       8  0.143958  0.182614  0.903378  None
# 7       9  0.449992  0.964743  0.242809  None
# 8      10  0.717517  0.973163  0.673969  None
# 9      11  0.604512  0.462088  0.986214  None
# 10     12  0.905127  0.415968  0.558411  None
# 11     13  0.483751  0.517467  0.886666  None
# 12     14  0.463231  0.009554  0.032222  None
# 13     15  0.700388  0.163386  0.788303  None
# 14     16  0.058124  0.128943  0.706653  None
# 15     17  0.339626  0.394312  0.293150  None
# 16     18  0.963115  0.545783  0.024147  None
# 17     19  0.878125  0.898241  0.726806  None
# 18     20  0.796752  0.417139  0.338135  None
# ...

# %%
df.loc[:,["c"]]= 54
df
# Out:
#            b         d         e   c
# 0   0.924005  0.590092  0.248867  54
# 3   0.146651  0.227090  0.522606  54
# 4   0.634405  0.296164  0.907977  54
# 5   0.360890  0.623124  0.115997  54
# 6   0.300445  0.783224  0.448824  54
# 7   0.875309  0.010303  0.435803  54
# 8   0.143958  0.182614  0.903378  54
# 9   0.449992  0.964743  0.242809  54
# 10  0.717517  0.973163  0.673969  54
# 11  0.604512  0.462088  0.986214  54
# 12  0.905127  0.415968  0.558411  54
# 13  0.483751  0.517467  0.886666  54
# 14  0.463231  0.009554  0.032222  54
# 15  0.700388  0.163386  0.788303  54
# 16  0.058124  0.128943  0.706653  54
# 17  0.339626  0.394312  0.293150  54
# 18  0.963115  0.545783  0.024147  54
# 19  0.878125  0.898241  0.726806  54
# 20  0.796752  0.417139  0.338135  54
# 21  0.364003  0.509557  0.986542  54
# 22  0.044668  0.496377  0.314951  54
# 23  0.676809  0.123125  0.190474  54
# 24  0.968860  0.196488  0.965115  54
# 25  0.330543  0.555490  0.508890  54
# ...

# %%
import pandas as pd
ddf = pd.DataFrame({
    "name":["a", "b","c","d"],
    "age":[21,20,np.nan,22],
    "born":[pd.NaT, 1920,1939, 2002]
})
ddf
# Out:
#   name   age  born
# 0    a  21.0   NaT
# 1    b  20.0  1920
# 2    c   NaN  1939
# 3    d  22.0  2002

# %%
ddf.dropna()
# Out:
#   name   age  born
# 1    b  20.0  1920
# 3    d  22.0  2002

# %%
# Out:
#    StudentID  HoursStudied  Grade Passed  Attendance
# 0        201          15.5   88.0    Yes        95.0
# 1        202           8.0   62.0     No        88.0
# 2        203           NaN   75.0    Yes        90.0
# 3        204          12.0    NaN    Yes        79.0
# 4        205           5.5   45.0     No         NaN
# 5        206          18.0   95.0    Yes        98.0

# %%
df =pd.read_csv('/Users/nikhilbishnoi/Desktop/python/friendly.csv')
df
# Out:
#    StudentID  HoursStudied  Grade Passed  Attendance
# 0        201          15.5   88.0    Yes        95.0
# 1        202           8.0   62.0     No        88.0
# 2        203           NaN   75.0    Yes        90.0
# 3        204          12.0    NaN    Yes        79.0
# 4        205           5.5   45.0     No         NaN
# 5        206          18.0   95.0    Yes        98.0

# %%
df = pd.read_csv("/Users/nikhilbishnoi/Downloads/train.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[188], line 1
# ----> 1 df = pd.read_csv("/Users/nikhilbishnoi/Downloads/train.csv")
#       2 df
#
# File ~/Desktop/python/.venv/lib/python3.14/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...

# %%
df.head(5)
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
df.shape
# Out:
# (418, 2)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
# dtypes: int64(2)
# memory usage: 6.7 KB

# %%
df.reset_index()
df.loc[0:2, ["Survived","PassengerId"]]
# Out:
#    Survived  PassengerId
# 0         0          892
# 1         1          893
# 2         0          894

# %%
print(df[df["Survived"]==1])
# Out:
#      PassengerId  Survived
# 1            893         1
# 4            896         1
# 6            898         1
# 8            900         1
# 12           904         1
# ..           ...       ...
# 409         1301         1
# 410         1302         1
# 411         1303         1
# 412         1304         1
# 414         1306         1
#
# [152 rows x 2 columns]

# %%
import pandas as pd
df = pd.read_csv("/Users/nikhilbishnoi/Downloads/Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.bar(df["SepalLengthCm"],df["SepalWidthCm"])
plt.show()
